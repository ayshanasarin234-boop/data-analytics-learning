# %%
# This notebook is my first Python practice file.
# It stores basic personal details and performs simple calculations.
# It also demonstrates how Python handles errors.

# %%
name = "Aysha"
age= 20
city= "Thiruvananthapuram"
print("Name:",name)
print("age:",age)
print("city:",city)
# Out:
# Name: Aysha
# age: 20
# city: Thiruvananthapuram

# %%
age_months=age*12
age_days=age*365
age_hours=age*24
print("age in months:",age_months)
print("age in days:",age_days)
print("age in hours:",age_hours)
# Out:
# age in months: 240
# age in days: 7300
# age in hours: 480

# %%
name=reniya
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 name=reniya
#
# NameError: name 'reniya' is not defined

# %%
# This error occurs because I wrote name = reniya without quotes. Python treats reniya as a variable, but it is not defined anywhere.So it gives a NameError saying that 'reniya' is not defined.
#To fix this, I should write it as a string using quotes: 
name = "reniya"
