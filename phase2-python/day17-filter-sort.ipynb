# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\AYSHA NASARIN\OneDrive\Documents\day17_demo.csv")
df.shape
# Out:
# (15, 8)

# %%
df.head(15)
# Out:
#     OrderID        Date Region            Product   Category  Sales  Profit  \
# 0      1001  2024-01-05  South  Avil Milk Classic  Beverages    450      80
# 1      1002  2024-01-06  North    Chocolate Shake  Beverages    600     120
# 2      1003  2024-01-07   East    Strawberry Milk  Beverages    300      40
# 3      1004  2024-01-08   West  Avil Milk Premium  Beverages    750     200
# 4      1005  2024-01-09  South        Cold Coffee  Beverages    500      60
# 5      1006  2024-01-10  North      Vanilla Shake  Beverages    650     150
# 6      1007  2024-01-11   East          Black Tea  Beverages    200      30
# 7      1008  2024-01-12   West          Green Tea  Beverages    350      70
# 8      1009  2024-01-13  South  Avil Milk Special  Beverages    800     250
# 9      1010  2024-01-14  North    Chocolate Shake  Beverages    550      90
# 10     1011  2024-01-15   East    Strawberry Milk  Beverages    400      60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   15 non-null     int64
#  1   Date      15 non-null     object
#  2   Region    15 non-null     object
#  3   Product   15 non-null     object
#  4   Category  15 non-null     object
#  5   Sales     15 non-null     int64
#  6   Profit    15 non-null     int64
#  7   Quantity  15 non-null     int64
# dtypes: int64(4), object(4)
# memory usage: 1.1+ KB

# %%
df[['Product','Profit']] 
# This shows only product names and their profits, helping focus on product performance.
# Out:
#               Product  Profit
# 0   Avil Milk Classic      80
# 1     Chocolate Shake     120
# 2     Strawberry Milk      40
# 3   Avil Milk Premium     200
# 4         Cold Coffee      60
# 5       Vanilla Shake     150
# 6           Black Tea      30
# 7           Green Tea      70
# 8   Avil Milk Special     250
# 9     Chocolate Shake      90
# 10    Strawberry Milk      60
# 11        Cold Coffee     180
# 12      Vanilla Shake      75
# 13  Avil Milk Premium     300
# 14          Black Tea      35

# %%
df[df['Sales'] > df['Sales'].mean()]
# This filters transactions where sales are above average, highlighting high-performing sales.
# Out:
#     OrderID        Date Region            Product   Category  Sales  Profit  \
# 1      1002  2024-01-06  North    Chocolate Shake  Beverages    600     120
# 3      1004  2024-01-08   West  Avil Milk Premium  Beverages    750     200
# 5      1006  2024-01-10  North      Vanilla Shake  Beverages    650     150
# 8      1009  2024-01-13  South  Avil Milk Special  Beverages    800     250
# 9      1010  2024-01-14  North    Chocolate Shake  Beverages    550      90
# 11     1012  2024-01-16   West        Cold Coffee  Beverages    700     180
# 13     1014  2024-01-18  North  Avil Milk Premium  Beverages    900     300
#
#     Quantity
# 1         15
# 3         20
# 5         18
# 8         22
# 9         14
# 11        19
# 13        25

# %%
df.sort_values(by='Sales', ascending=False)
# This sorts the dataset from highest to lowest sales, helping identify top-performing transactions.
# Out:
#     OrderID        Date Region            Product   Category  Sales  Profit  \
# 13     1014  2024-01-18  North  Avil Milk Premium  Beverages    900     300
# 8      1009  2024-01-13  South  Avil Milk Special  Beverages    800     250
# 3      1004  2024-01-08   West  Avil Milk Premium  Beverages    750     200
# 11     1012  2024-01-16   West        Cold Coffee  Beverages    700     180
# 5      1006  2024-01-10  North      Vanilla Shake  Beverages    650     150
# 1      1002  2024-01-06  North    Chocolate Shake  Beverages    600     120
# 9      1010  2024-01-14  North    Chocolate Shake  Beverages    550      90
# 4      1005  2024-01-09  South        Cold Coffee  Beverages    500      60
# 12     1013  2024-01-17  South      Vanilla Shake  Beverages    480      75
# 0      1001  2024-01-05  South  Avil Milk Classic  Beverages    450      80
# 10     1011  2024-01-15   East    Strawberry Milk  Beverages    400      60
# ...

# %%
df[(df['Sales'] > 500) & (df['Profit'] > 100)]
# This shows transactions with both high sales and high profit, indicating the most valuable business deals.
# Out:
#     OrderID        Date Region            Product   Category  Sales  Profit  \
# 1      1002  2024-01-06  North    Chocolate Shake  Beverages    600     120
# 3      1004  2024-01-08   West  Avil Milk Premium  Beverages    750     200
# 5      1006  2024-01-10  North      Vanilla Shake  Beverages    650     150
# 8      1009  2024-01-13  South  Avil Milk Special  Beverages    800     250
# 11     1012  2024-01-16   West        Cold Coffee  Beverages    700     180
# 13     1014  2024-01-18  North  Avil Milk Premium  Beverages    900     300
#
#     Quantity
# 1         15
# 3         20
# 5         18
# 8         22
# 11        19
# 13        25
